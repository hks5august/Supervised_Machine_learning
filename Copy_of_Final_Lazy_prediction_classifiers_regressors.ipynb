# %%
#upgrade pandas since some of the function else won't work and make sure to click on RESTART RUNTIME
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Collecting pandas
#   Downloading pandas-1.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 4.2 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.2 which is incompatible.
# Successfully installed pandas-1.3.2

# %% [markdown]
# Insatll lazypredict package, which is not part of google colab bydefault.
# After installation, make sure to click on RESTART RUNTIME

# %%
#Install lazypredict for multiiple alogorithms run at a time
# !pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.9-py2.py3-none-any.whl (12 kB)
# Collecting scikit-learn==0.23.1
#   Downloading scikit_learn-0.23.1-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 8.3 MB/s
# Collecting pandas==1.0.5
#   Downloading pandas-1.0.5-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 64.5 MB/s
# Collecting xgboost==1.1.1
#   Downloading xgboost-1.1.1-py3-none-manylinux2010_x86_64.whl (127.6 MB)
#      |████████████████████████████████| 127.6 MB 16 kB/s
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.15.0)
# Collecting scipy==1.5.4
#   Downloading scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 949 bytes/s
# Collecting joblib==1.0.0
#   Downloading joblib-1.0.0-py3-none-any.whl (302 kB)
#      |████████████████████████████████| 302 kB 54.5 MB/s
# Collecting numpy==1.19.1
#   Downloading numpy-1.19.1-cp37-cp37m-manylinux2010_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 7.7 kB/s
# Collecting lightgbm==2.3.1
#   Downloading lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 31.5 MB/s
# Collecting pytest==5.4.3
#   Downloading pytest-5.4.3-py3-none-any.whl (248 kB)
#      |████████████████████████████████| 248 kB 54.8 MB/s
# Collecting PyYAML==5.3.1
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
#      |████████████████████████████████| 269 kB 38.5 MB/s
# Collecting tqdm==4.56.0
#   Downloading tqdm-4.56.0-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 858 kB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2018.9)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (8.8.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (4.6.4)
# Collecting pluggy<1.0,>=0.12
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.2.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (1.10.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest==5.4.3->lazypredict) (2.4.7)
# Building wheels for collected packages: PyYAML
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44635 sha256=3133ebcf3bc46d7278258d52eca34c9545ea4c4782b4d749def6e82f10cd0c7b
#   Stored in directory: /root/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
# Successfully built PyYAML
# Installing collected packages: numpy, threadpoolctl, scipy, joblib, scikit-learn, pluggy, xgboost, tqdm, PyYAML, pytest, pandas, lightgbm, lazypredict
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.0.1
#     Uninstalling joblib-1.0.1:
#       Successfully uninstalled joblib-1.0.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.0
#     Uninstalling tqdm-4.62.0:
#       Successfully uninstalled tqdm-4.62.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.2
#     Uninstalling pandas-1.3.2:
#       Successfully uninstalled pandas-1.3.2
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires numpy~=1.19.2, but you have numpy 1.19.1 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.0.5 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed PyYAML-5.3.1 joblib-1.0.0 lazypredict-0.2.9 lightgbm-2.3.1 numpy-1.19.1 pandas-1.0.5 pluggy-0.13.1 pytest-5.4.3 scikit-learn-0.23.1 scipy-1.5.4 threadpoolctl-2.2.0 tqdm-4.56.0 xgboost-1.1.1

# %% [markdown]
# Load all the required packages

# %%
# import necessary modules
import warnings
warnings.filterwarnings('ignore')
import time 
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier,LazyRegressor

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load Breast cancer cell line data with different subtypes.
# Here, we label : Normal-like = 0, Basal = 1, Luminal = 3, Claudin-low = 3, since, to run package, we need labels as numeric values

# %%
#Load data
data = pd.read_table('https://raw.githubusercontent.com/pine-bio-support/ML-Demo/master/CellLines_52samples_ExprData_T1_new.txt',sep='\t',header=(0))
data.shape
# Out:
# (6917, 53)

# %% [markdown]
# Check Data

# %%
data.head
# Out:
# <bound method NDFrame.head of                    id  184A1  184B5  21MT1  ...  UACC893  ZR751  ZR7530  ZR75B
# 0               class   0.00   0.00   1.00  ...     2.00   2.00    2.00   2.00
# 1     ENSG00000000419   6.06   5.25   5.15  ...     5.70   5.85    5.34   5.07
# 2     ENSG00000001036   4.47   5.39   5.28  ...     5.40   4.27    5.03   5.68
# 3     ENSG00000001084   4.47   6.00   5.77  ...     4.35   2.49    5.89   4.37
# 4     ENSG00000001497   5.27   4.27   6.58  ...     4.89   5.33    4.23   6.03
# ...               ...    ...    ...    ...  ...      ...    ...     ...    ...
# 6912  ENSG00000270016   0.04   0.00   0.00  ...     0.00   0.00    0.27   0.00
# 6913  ENSG00000270149   4.39   4.98   4.78  ...     6.30   5.38    3.93   3.99
# 6914  ENSG00000270161   4.09   3.90   6.49  ...     5.56   2.84    3.87   4.67
# 6915  ENSG00000270168   2.17   1.60   2.70  ...     5.60   7.68    5.25   7.21
# 6916  ENSG00000270170   3.99   4.65   5.92  ...     4.95   4.07    3.81   4.25
#
# [6917 rows x 53 columns]>

# %% [markdown]
# First, Transpose Data
# Then, Take expression data and labels into two python objects as X and y, respectively

# %%
data=data.drop(['id'], axis = 1) 

dataT = np.transpose(data)

X = dataT.iloc[:, 1:].values
y = dataT.iloc[:, 0].values

# %% [markdown]
# Prepare training and test data. Split whole data into 80:20 ratio as training and test data

# %%
#Split training and test data into 80:20 ratio
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %% [markdown]
# Check training data

# %%
X_train
# Out:
# array([[4.15, 5.9 , 5.26, ..., 3.04, 5.17, 5.42],
#        [4.69, 4.72, 5.97, ..., 4.08, 3.3 , 4.37],
#        [7.29, 5.47, 4.5 , ..., 4.92, 1.12, 4.5 ],
#        ...,
#        [5.25, 5.39, 6.  , ..., 3.9 , 1.6 , 4.65],
#        [5.32, 6.11, 5.78, ..., 3.68, 4.19, 3.85],
#        [6.39, 5.3 , 4.16, ..., 4.37, 3.92, 6.18]])

# %% [markdown]
# Check labels of training data

# %%
y_train
# Out:
# array([1., 2., 2., 3., 0., 2., 3., 1., 2., 2., 1., 2., 2., 2., 1., 2., 2.,
#        2., 3., 2., 2., 2., 1., 1., 2., 2., 1., 0., 1., 1., 2., 2., 0., 2.,
#        3., 2., 1., 3., 0., 2., 2.])

# %% [markdown]
# Create a lazyClassifier model

# %%
model=LazyClassifier(verbose=0,predictions=True)

# %% [markdown]
# Fit models on training and test data

# %%
# fit and train the model 
start_time_1=time.time()
models_c,predictions_c=model.fit(X_train, X_test, y_train, y_test)
end_time_1=time.time()
# Out:
# 100%|██████████| 29/29 [00:12<00:00,  2.41it/s]

# %% [markdown]
# Check performance on training data

# %%
models_c
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# LinearSVC                          1.00  ...        0.33
# KNeighborsClassifier               1.00  ...        0.17
# RidgeClassifierCV                  1.00  ...        0.26
# RidgeClassifier                    1.00  ...        0.21
# PassiveAggressiveClassifier        1.00  ...        0.28
# NearestCentroid                    1.00  ...        0.22
# LogisticRegression                 1.00  ...        1.27
# BaggingClassifier                  1.00  ...        0.46
# LGBMClassifier                     1.00  ...        0.86
# BernoulliNB                        1.00  ...        0.21
# RandomForestClassifier             0.91  ...        0.41
# LinearDiscriminantAnalysis         0.91  ...        0.32
# ExtraTreesClassifier               0.91  ...        0.30
# CalibratedClassifierCV             0.91  ...        0.62
# Perceptron                         0.82  ...        0.24
# SGDClassifier                      0.82  ...        0.24
# ExtraTreeClassifier                0.73  ...        0.17
# SVC                                0.91  ...        0.25
# AdaBoostClassifier                 0.91  ...        1.51
# DecisionTreeClassifier             0.91  ...        0.20
# XGBClassifier                      0.82  ...        1.98
# QuadraticDiscriminantAnalysis      0.36  ...        0.27
# DummyClassifier                    0.45  ...        0.16
# LabelPropagation                   0.09  ...        0.20
# LabelSpreading                     0.09  ...        0.25
# GaussianNB                         0.45  ...        0.19
#
# [26 rows x 5 columns]

# %% [markdown]
# Check performance on test data

# %%
predictions_c
# Out:
#     AdaBoostClassifier  BaggingClassifier  ...  XGBClassifier  LGBMClassifier
# 0                 3.00               3.00  ...           1.00            3.00
# 1                 2.00               2.00  ...           2.00            2.00
# 2                 1.00               0.00  ...           0.00            0.00
# 3                 2.00               2.00  ...           2.00            2.00
# 4                 2.00               2.00  ...           2.00            2.00
# 5                 1.00               1.00  ...           2.00            1.00
# 6                 1.00               1.00  ...           1.00            1.00
# 7                 1.00               1.00  ...           1.00            1.00
# 8                 2.00               2.00  ...           2.00            2.00
# 9                 1.00               1.00  ...           1.00            1.00
# 10                2.00               2.00  ...           2.00            2.00
#
# [11 rows x 26 columns]

# %% [markdown]
# Regression model

# %%
# fit all models
reg = LazyRegressor(predictions=True)
models_r, predictions_r = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 42/42 [00:57<00:00,  1.36s/it]

# %% [markdown]
# Performance on training data

# %%
models_r
# Out:
#                                        Adjusted R-Squared  ...  Time Taken
# Model                                                      ...
# Lars                          607211751963996700278784.00  ...        1.51
# SGDRegressor                  250445316708862741446656.00  ...        0.22
# PassiveAggressiveRegressor                           1.01  ...        0.23
# MLPRegressor                                         1.01  ...        0.63
# GaussianProcessRegressor                             1.01  ...        0.21
# KernelRidge                                          1.01  ...        0.22
# DummyRegressor                                       1.00  ...        0.15
# LarsCV                                               1.00  ...        5.57
# LassoLarsIC                                          1.00  ...        0.37
# Lasso                                                1.00  ...        0.25
# LassoLars                                            1.00  ...        0.25
# DecisionTreeRegressor                                1.00  ...        0.25
# ElasticNet                                           1.00  ...        0.21
# OrthogonalMatchingPursuit                            1.00  ...        0.21
# OrthogonalMatchingPursuitCV                          1.00  ...        1.01
# SVR                                                  1.00  ...        0.23
# XGBRegressor                                         1.00  ...        1.30
# AdaBoostRegressor                                    1.00  ...        1.56
# NuSVR                                                1.00  ...        0.23
# PoissonRegressor                                     1.00  ...        0.38
# BaggingRegressor                                     1.00  ...        0.44
# GradientBoostingRegressor                            1.00  ...        4.69
# LGBMRegressor                                        1.00  ...        0.45
# KNeighborsRegressor                                  1.00  ...        0.27
# HistGradientBoostingRegressor                        1.00  ...        3.45
# RandomForestRegressor                                1.00  ...        2.68
# ExtraTreeRegressor                                   1.00  ...        0.22
# LassoLarsCV                                          1.00  ...        0.92
# LassoCV                                              1.00  ...       12.88
# HuberRegressor                                       1.00  ...        1.18
# GeneralizedLinearRegressor                           1.00  ...        0.26
# TweedieRegressor                                     1.00  ...        0.29
# Ridge                                                1.00  ...        0.21
# RidgeCV                                              1.00  ...        0.27
# BayesianRidge                                        1.00  ...        0.95
# LinearRegression                                     1.00  ...        0.27
# TransformedTargetRegressor                           1.00  ...        0.22
# LinearSVR                                            1.00  ...        0.94
# ElasticNetCV                                         1.00  ...        9.83
# ExtraTreesRegressor                                  1.00  ...        1.29
#
# [40 rows x 4 columns]

# %% [markdown]
# Performance on Test data

# %%
predictions_r
# Out:
#     AdaBoostRegressor  BaggingRegressor  ...  XGBRegressor  LGBMRegressor
# 0                2.00              1.80  ...          2.00           2.16
# 1                2.00              2.00  ...          2.00           2.13
# 2                2.00              2.00  ...          2.00           2.09
# 3                2.00              2.20  ...          2.00           1.54
# 4                1.00              1.50  ...          1.92           1.00
# 5                1.00              0.80  ...          1.00           0.95
# 6                2.00              2.20  ...          2.33           2.35
# 7                2.00              2.00  ...          1.93           2.16
# 8                2.00              2.30  ...          3.00           2.28
# 9                1.00              1.40  ...          1.92           1.06
# 10               2.00              2.10  ...          1.99           2.14
#
# [11 rows x 40 columns]
